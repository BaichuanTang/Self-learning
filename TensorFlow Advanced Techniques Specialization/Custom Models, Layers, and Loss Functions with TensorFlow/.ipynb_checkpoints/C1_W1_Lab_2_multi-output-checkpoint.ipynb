# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot

# %%
import os
os.environ["PATH"] += os.pathsep + 'D:/Graphviz/bin/'  #注意修改你的路径

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(128, activation='relu')(input_layer)
second_dense = Dense(128, activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(1, name='y1_output')(second_dense)
third_dense = Dense(64, activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(1, name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Plot model graph
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model2.png')

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 0s 114us/sample - loss: 6.8539 - y1_output_loss: 1.9744 - y2_output_loss: 4.8264 - y1_output_root_mean_squared_error: 1.4082 - y2_output_root_mean_squared_error: 2.2070 - val_loss: 4.9777 - val_y1_output_loss: 1.9853 - val_y2_output_loss: 2.8240 - val_y1_output_root_mean_squared_error: 1.4336 - val_y2_output_root_mean_squared_error: 1.7096
# Epoch 2/500
# 614/614 [==============================] - 0s 107us/sample - loss: 6.3076 - y1_output_loss: 1.7389 - y2_output_loss: 4.5353 - y1_output_root_mean_squared_error: 1.3207 - y2_output_root_mean_squared_error: 2.1362 - val_loss: 5.1256 - val_y1_output_loss: 1.4648 - val_y2_output_loss: 3.4878 - val_y1_output_root_mean_squared_error: 1.2315 - val_y2_output_root_mean_squared_error: 1.8997
# Epoch 3/500
# 614/614 [==============================] - 0s 122us/sample - loss: 7.6859 - y1_output_loss: 2.2586 - y2_output_loss: 5.4275 - y1_output_root_mean_squared_error: 1.4988 - y2_output_root_mean_squared_error: 2.3323 - val_loss: 4.6468 - val_y1_output_loss: 1.4913 - val_y2_output_loss: 3.0110 - val_y1_output_root_mean_squared_error: 1.2379 - val_y2_output_root_mean_squared_error: 1.7648
# Epoch 4/500
# 614/614 [==============================] - 0s 101us/sample - loss: 6.6727 - y1_output_loss: 1.8660 - y2_output_loss: 4.8225 - y1_output_root_mean_squared_error: 1.3643 - y2_output_root_mean_squared_error: 2.1935 - val_loss: 11.8813 - val_y1_output_loss: 3.5724 - val_y2_output_loss: 7.8893 - val_y1_output_root_mean_squared_error: 1.9244 - val_y2_output_root_mean_squared_error: 2.8597
# Epoch 5/500
# 614/614 [==============================] - 0s 106us/sample - loss: 5.6773 - y1_output_loss: 1.6164 - y2_output_loss: 4.0692 - y1_output_root_mean_squared_error: 1.2761 - y2_output_root_mean_squared_error: 2.0122 - val_loss: 4.6439 - val_y1_output_loss: 1.3631 - val_y2_output_loss: 3.1201 - val_y1_output_root_mean_squared_error: 1.1880 - val_y2_output_root_mean_squared_error: 1.7979
# Epoch 6/500
# 614/614 [==============================] - 0s 104us/sample - loss: 5.7409 - y1_output_loss: 1.5809 - y2_output_loss: 4.1493 - y1_output_root_mean_squared_error: 1.2630 - y2_output_root_mean_squared_error: 2.0361 - val_loss: 3.4646 - val_y1_output_loss: 1.0710 - val_y2_output_loss: 2.2850 - val_y1_output_root_mean_squared_error: 1.0488 - val_y2_output_root_mean_squared_error: 1.5377
# Epoch 7/500
# 614/614 [==============================] - 0s 101us/sample - loss: 6.8376 - y1_output_loss: 1.9636 - y2_output_loss: 4.8391 - y1_output_root_mean_squared_error: 1.4012 - y2_output_root_mean_squared_error: 2.2078 - val_loss: 8.0057 - val_y1_output_loss: 3.8060 - val_y2_output_loss: 3.9158 - val_y1_output_root_mean_squared_error: 1.9854 - val_y2_output_root_mean_squared_error: 2.0159
# Epoch 8/500
# 614/614 [==============================] - 0s 101us/sample - loss: 5.0149 - y1_output_loss: 1.3210 - y2_output_loss: 3.6520 - y1_output_root_mean_squared_error: 1.1538 - y2_output_root_mean_squared_error: 1.9193 - val_loss: 3.7286 - val_y1_output_loss: 0.8438 - val_y2_output_loss: 2.7624 - val_y1_output_root_mean_squared_error: 0.9321 - val_y2_output_root_mean_squared_error: 1.6911
# Epoch 9/500
# 614/614 [==============================] - 0s 103us/sample - loss: 5.0811 - y1_output_loss: 1.2216 - y2_output_loss: 3.8870 - y1_output_root_mean_squared_error: 1.1100 - y2_output_root_mean_squared_error: 1.9619 - val_loss: 5.6055 - val_y1_output_loss: 1.3238 - val_y2_output_loss: 4.0884 - val_y1_output_root_mean_squared_error: 1.1703 - val_y2_output_root_mean_squared_error: 2.0581
# Epoch 10/500
# 614/614 [==============================] - 0s 103us/sample - loss: 4.3705 - y1_output_loss: 1.1995 - y2_output_loss: 3.1555 - y1_output_root_mean_squared_error: 1.0926 - y2_output_root_mean_squared_error: 1.7823 - val_loss: 4.3125 - val_y1_output_loss: 0.8417 - val_y2_output_loss: 3.3263 - val_y1_output_root_mean_squared_error: 0.9320 - val_y2_output_root_mean_squared_error: 1.8558
# Epoch 11/500
# 614/614 [==============================] - 0s 104us/sample - loss: 4.8143 - y1_output_loss: 1.1923 - y2_output_loss: 3.5842 - y1_output_root_mean_squared_error: 1.0951 - y2_output_root_mean_squared_error: 1.9013 - val_loss: 3.7429 - val_y1_output_loss: 0.9541 - val_y2_output_loss: 2.6553 - val_y1_output_root_mean_squared_error: 0.9940 - val_y2_output_root_mean_squared_error: 1.6598
# Epoch 12/500
# 614/614 [==============================] - 0s 104us/sample - loss: 5.8238 - y1_output_loss: 1.4505 - y2_output_loss: 4.3855 - y1_output_root_mean_squared_error: 1.2008 - y2_output_root_mean_squared_error: 2.0933 - val_loss: 4.2642 - val_y1_output_loss: 0.8979 - val_y2_output_loss: 3.2184 - val_y1_output_root_mean_squared_error: 0.9642 - val_y2_output_root_mean_squared_error: 1.8261
# Epoch 13/500
# 614/614 [==============================] - 0s 103us/sample - loss: 5.1205 - y1_output_loss: 1.3997 - y2_output_loss: 3.6845 - y1_output_root_mean_squared_error: 1.1870 - y2_output_root_mean_squared_error: 1.9265 - val_loss: 3.6253 - val_y1_output_loss: 1.0387 - val_y2_output_loss: 2.4948 - val_y1_output_root_mean_squared_error: 1.0251 - val_y2_output_root_mean_squared_error: 1.6045
# Epoch 14/500
# 614/614 [==============================] - 0s 101us/sample - loss: 6.3848 - y1_output_loss: 1.8211 - y2_output_loss: 4.5458 - y1_output_root_mean_squared_error: 1.3558 - y2_output_root_mean_squared_error: 2.1323 - val_loss: 8.5714 - val_y1_output_loss: 2.6425 - val_y2_output_loss: 5.6250 - val_y1_output_root_mean_squared_error: 1.6540 - val_y2_output_root_mean_squared_error: 2.4157
# Epoch 15/500
# 614/614 [==============================] - 0s 104us/sample - loss: 6.1454 - y1_output_loss: 1.7984 - y2_output_loss: 4.3440 - y1_output_root_mean_squared_error: 1.3465 - y2_output_root_mean_squared_error: 2.0814 - val_loss: 6.9231 - val_y1_output_loss: 1.1734 - val_y2_output_loss: 5.5524 - val_y1_output_root_mean_squared_error: 1.0988 - val_y2_output_root_mean_squared_error: 2.3908
# Epoch 16/500
# 614/614 [==============================] - 0s 103us/sample - loss: 3.9345 - y1_output_loss: 0.9813 - y2_output_loss: 2.9708 - y1_output_root_mean_squared_error: 0.9884 - y2_output_root_mean_squared_error: 1.7197 - val_loss: 10.5116 - val_y1_output_loss: 3.2478 - val_y2_output_loss: 7.0107 - val_y1_output_root_mean_squared_error: 1.8241 - val_y2_output_root_mean_squared_error: 2.6803
# Epoch 17/500
# 614/614 [==============================] - 0s 103us/sample - loss: 5.6607 - y1_output_loss: 1.5673 - y2_output_loss: 4.0673 - y1_output_root_mean_squared_error: 1.2562 - y2_output_root_mean_squared_error: 2.0206 - val_loss: 3.7042 - val_y1_output_loss: 1.0740 - val_y2_output_loss: 2.5466 - val_y1_output_root_mean_squared_error: 1.0511 - val_y2_output_root_mean_squared_error: 1.6122
# Epoch 18/500
# 614/614 [==============================] - 0s 104us/sample - loss: 3.4956 - y1_output_loss: 0.7871 - y2_output_loss: 2.6785 - y1_output_root_mean_squared_error: 0.8910 - y2_output_root_mean_squared_error: 1.6437 - val_loss: 4.8851 - val_y1_output_loss: 0.6370 - val_y2_output_loss: 4.0798 - val_y1_output_root_mean_squared_error: 0.8092 - val_y2_output_root_mean_squared_error: 2.0568
# Epoch 19/500
# 614/614 [==============================] - 0s 101us/sample - loss: 4.7415 - y1_output_loss: 1.1121 - y2_output_loss: 3.6194 - y1_output_root_mean_squared_error: 1.0562 - y2_output_root_mean_squared_error: 1.9042 - val_loss: 4.1899 - val_y1_output_loss: 1.3131 - val_y2_output_loss: 2.7372 - val_y1_output_root_mean_squared_error: 1.1654 - val_y2_output_root_mean_squared_error: 1.6828
# Epoch 20/500
# 614/614 [==============================] - 0s 103us/sample - loss: 6.6714 - y1_output_loss: 1.8206 - y2_output_loss: 4.8417 - y1_output_root_mean_squared_error: 1.3515 - y2_output_root_mean_squared_error: 2.2011 - val_loss: 5.3288 - val_y1_output_loss: 1.2123 - val_y2_output_loss: 3.9294 - val_y1_output_root_mean_squared_error: 1.1204 - val_y2_output_root_mean_squared_error: 2.0183
# Epoch 21/500
# 614/614 [==============================] - 0s 104us/sample - loss: 5.7891 - y1_output_loss: 1.5878 - y2_output_loss: 4.1597 - y1_output_root_mean_squared_error: 1.2654 - y2_output_root_mean_squared_error: 2.0464 - val_loss: 4.1533 - val_y1_output_loss: 0.9918 - val_y2_output_loss: 3.0984 - val_y1_output_root_mean_squared_error: 0.9974 - val_y2_output_root_mean_squared_error: 1.7772
# Epoch 22/500
# 614/614 [==============================] - 0s 103us/sample - loss: 5.4921 - y1_output_loss: 1.3279 - y2_output_loss: 4.1404 - y1_output_root_mean_squared_error: 1.1513 - y2_output_root_mean_squared_error: 2.0412 - val_loss: 3.0435 - val_y1_output_loss: 0.8937 - val_y2_output_loss: 2.0540 - val_y1_output_root_mean_squared_error: 0.9597 - val_y2_output_root_mean_squared_error: 1.4569
# Epoch 23/500
# 614/614 [==============================] - 0s 101us/sample - loss: 4.0334 - y1_output_loss: 1.1596 - y2_output_loss: 2.8640 - y1_output_root_mean_squared_error: 1.0778 - y2_output_root_mean_squared_error: 1.6946 - val_loss: 4.1576 - val_y1_output_loss: 1.1645 - val_y2_output_loss: 2.8497 - val_y1_output_root_mean_squared_error: 1.0972 - val_y2_output_root_mean_squared_error: 1.7187
# Epoch 24/500
# 614/614 [==============================] - 0s 106us/sample - loss: 4.2363 - y1_output_loss: 1.0877 - y2_output_loss: 3.1590 - y1_output_root_mean_squared_error: 1.0469 - y2_output_root_mean_squared_error: 1.7721 - val_loss: 7.8245 - val_y1_output_loss: 1.0529 - val_y2_output_loss: 6.5127 - val_y1_output_root_mean_squared_error: 1.0449 - val_y2_output_root_mean_squared_error: 2.5947
# Epoch 25/500
# 614/614 [==============================] - 0s 104us/sample - loss: 5.2283 - y1_output_loss: 1.3196 - y2_output_loss: 3.8866 - y1_output_root_mean_squared_error: 1.1471 - y2_output_root_mean_squared_error: 1.9780 - val_loss: 2.7688 - val_y1_output_loss: 0.6318 - val_y2_output_loss: 2.0412 - val_y1_output_root_mean_squared_error: 0.8072 - val_y2_output_root_mean_squared_error: 1.4551
# Epoch 26/500
# 614/614 [==============================] - 0s 103us/sample - loss: 3.4115 - y1_output_loss: 0.7008 - y2_output_loss: 2.6925 - y1_output_root_mean_squared_error: 0.8383 - y2_output_root_mean_squared_error: 1.6458 - val_loss: 6.0270 - val_y1_output_loss: 0.6945 - val_y2_output_loss: 5.1343 - val_y1_output_root_mean_squared_error: 0.8464 - val_y2_output_root_mean_squared_error: 2.3045
# Epoch 27/500
# 614/614 [==============================] - 0s 111us/sample - loss: 3.8519 - y1_output_loss: 0.8247 - y2_output_loss: 3.0117 - y1_output_root_mean_squared_error: 0.9124 - y2_output_root_mean_squared_error: 1.7376 - val_loss: 3.0123 - val_y1_output_loss: 0.6972 - val_y2_output_loss: 2.2155 - val_y1_output_root_mean_squared_error: 0.8467 - val_y2_output_root_mean_squared_error: 1.5151
# Epoch 28/500
# 614/614 [==============================] - 0s 104us/sample - loss: 3.1766 - y1_output_loss: 0.7022 - y2_output_loss: 2.4648 - y1_output_root_mean_squared_error: 0.8388 - y2_output_root_mean_squared_error: 1.5726 - val_loss: 2.9104 - val_y1_output_loss: 0.7395 - val_y2_output_loss: 2.0796 - val_y1_output_root_mean_squared_error: 0.8727 - val_y2_output_root_mean_squared_error: 1.4659
# Epoch 29/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.7894 - y1_output_loss: 0.5973 - y2_output_loss: 2.1768 - y1_output_root_mean_squared_error: 0.7726 - y2_output_root_mean_squared_error: 1.4807 - val_loss: 3.1038 - val_y1_output_loss: 0.6534 - val_y2_output_loss: 2.3485 - val_y1_output_root_mean_squared_error: 0.8215 - val_y2_output_root_mean_squared_error: 1.5585
# Epoch 30/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.9835 - y1_output_loss: 0.6804 - y2_output_loss: 2.2915 - y1_output_root_mean_squared_error: 0.8283 - y2_output_root_mean_squared_error: 1.5157 - val_loss: 3.1650 - val_y1_output_loss: 0.5650 - val_y2_output_loss: 2.5170 - val_y1_output_root_mean_squared_error: 0.7491 - val_y2_output_root_mean_squared_error: 1.6136
# Epoch 31/500
# 614/614 [==============================] - 0s 101us/sample - loss: 3.9794 - y1_output_loss: 0.9226 - y2_output_loss: 3.0210 - y1_output_root_mean_squared_error: 0.9650 - y2_output_root_mean_squared_error: 1.7459 - val_loss: 2.9503 - val_y1_output_loss: 0.5821 - val_y2_output_loss: 2.2700 - val_y1_output_root_mean_squared_error: 0.7732 - val_y2_output_root_mean_squared_error: 1.5338
# Epoch 32/500
# 614/614 [==============================] - 0s 104us/sample - loss: 4.7063 - y1_output_loss: 1.3239 - y2_output_loss: 3.3519 - y1_output_root_mean_squared_error: 1.1560 - y2_output_root_mean_squared_error: 1.8357 - val_loss: 3.0300 - val_y1_output_loss: 0.6273 - val_y2_output_loss: 2.3095 - val_y1_output_root_mean_squared_error: 0.7995 - val_y2_output_root_mean_squared_error: 1.5462
# Epoch 33/500
# 614/614 [==============================] - 0s 103us/sample - loss: 3.2184 - y1_output_loss: 0.6795 - y2_output_loss: 2.5189 - y1_output_root_mean_squared_error: 0.8246 - y2_output_root_mean_squared_error: 1.5932 - val_loss: 3.1133 - val_y1_output_loss: 0.9759 - val_y2_output_loss: 2.0414 - val_y1_output_root_mean_squared_error: 1.0047 - val_y2_output_root_mean_squared_error: 1.4504
# Epoch 34/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.7190 - y1_output_loss: 0.5537 - y2_output_loss: 2.1746 - y1_output_root_mean_squared_error: 0.7451 - y2_output_root_mean_squared_error: 1.4710 - val_loss: 7.9894 - val_y1_output_loss: 3.0393 - val_y2_output_loss: 4.6650 - val_y1_output_root_mean_squared_error: 1.7755 - val_y2_output_root_mean_squared_error: 2.1993
# Epoch 35/500
# 614/614 [==============================] - 0s 109us/sample - loss: 3.6054 - y1_output_loss: 0.7745 - y2_output_loss: 2.8107 - y1_output_root_mean_squared_error: 0.8769 - y2_output_root_mean_squared_error: 1.6842 - val_loss: 3.1968 - val_y1_output_loss: 0.7890 - val_y2_output_loss: 2.2973 - val_y1_output_root_mean_squared_error: 0.9040 - val_y2_output_root_mean_squared_error: 1.5426
# Epoch 36/500
# 614/614 [==============================] - 0s 104us/sample - loss: 11.4727 - y1_output_loss: 3.8649 - y2_output_loss: 7.5091 - y1_output_root_mean_squared_error: 1.9750 - y2_output_root_mean_squared_error: 2.7517 - val_loss: 2.2249 - val_y1_output_loss: 0.4580 - val_y2_output_loss: 1.7018 - val_y1_output_root_mean_squared_error: 0.6872 - val_y2_output_root_mean_squared_error: 1.3239
# Epoch 37/500
# 614/614 [==============================] - 0s 101us/sample - loss: 3.4852 - y1_output_loss: 0.8861 - y2_output_loss: 2.6352 - y1_output_root_mean_squared_error: 0.9414 - y2_output_root_mean_squared_error: 1.6121 - val_loss: 13.1311 - val_y1_output_loss: 1.7669 - val_y2_output_loss: 10.9611 - val_y1_output_root_mean_squared_error: 1.3525 - val_y2_output_root_mean_squared_error: 3.3618
# Epoch 38/500
# 614/614 [==============================] - 0s 104us/sample - loss: 4.8895 - y1_output_loss: 1.1568 - y2_output_loss: 3.7320 - y1_output_root_mean_squared_error: 1.0676 - y2_output_root_mean_squared_error: 1.9364 - val_loss: 4.6555 - val_y1_output_loss: 1.4569 - val_y2_output_loss: 3.0643 - val_y1_output_root_mean_squared_error: 1.2221 - val_y2_output_root_mean_squared_error: 1.7782
# Epoch 39/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.6733 - y1_output_loss: 0.5927 - y2_output_loss: 2.0770 - y1_output_root_mean_squared_error: 0.7687 - y2_output_root_mean_squared_error: 1.4430 - val_loss: 2.9759 - val_y1_output_loss: 0.5526 - val_y2_output_loss: 2.3257 - val_y1_output_root_mean_squared_error: 0.7554 - val_y2_output_root_mean_squared_error: 1.5509
# Epoch 40/500
# 614/614 [==============================] - 0s 107us/sample - loss: 5.2924 - y1_output_loss: 1.2108 - y2_output_loss: 4.0399 - y1_output_root_mean_squared_error: 1.1031 - y2_output_root_mean_squared_error: 2.0188 - val_loss: 2.8191 - val_y1_output_loss: 0.7454 - val_y2_output_loss: 1.9813 - val_y1_output_root_mean_squared_error: 0.8783 - val_y2_output_root_mean_squared_error: 1.4310
# Epoch 41/500
# 614/614 [==============================] - 0s 101us/sample - loss: 5.0590 - y1_output_loss: 1.3090 - y2_output_loss: 3.7423 - y1_output_root_mean_squared_error: 1.1474 - y2_output_root_mean_squared_error: 1.9345 - val_loss: 5.9554 - val_y1_output_loss: 1.5507 - val_y2_output_loss: 4.2018 - val_y1_output_root_mean_squared_error: 1.2667 - val_y2_output_root_mean_squared_error: 2.0859
# Epoch 42/500
# 614/614 [==============================] - 0s 99us/sample - loss: 2.6304 - y1_output_loss: 0.5638 - y2_output_loss: 2.0489 - y1_output_root_mean_squared_error: 0.7502 - y2_output_root_mean_squared_error: 1.4379 - val_loss: 3.7134 - val_y1_output_loss: 0.5060 - val_y2_output_loss: 3.0995 - val_y1_output_root_mean_squared_error: 0.7241 - val_y2_output_root_mean_squared_error: 1.7858
# Epoch 43/500
# 614/614 [==============================] - 0s 101us/sample - loss: 3.2619 - y1_output_loss: 0.6968 - y2_output_loss: 2.5876 - y1_output_root_mean_squared_error: 0.8355 - y2_output_root_mean_squared_error: 1.6012 - val_loss: 6.4356 - val_y1_output_loss: 0.6930 - val_y2_output_loss: 5.5934 - val_y1_output_root_mean_squared_error: 0.8452 - val_y2_output_root_mean_squared_error: 2.3919
# Epoch 44/500
# 614/614 [==============================] - 0s 101us/sample - loss: 3.4469 - y1_output_loss: 0.7052 - y2_output_loss: 2.7637 - y1_output_root_mean_squared_error: 0.8360 - y2_output_root_mean_squared_error: 1.6577 - val_loss: 11.1057 - val_y1_output_loss: 1.6686 - val_y2_output_loss: 9.0434 - val_y1_output_root_mean_squared_error: 1.3153 - val_y2_output_root_mean_squared_error: 3.0620
# Epoch 45/500
# 614/614 [==============================] - 0s 101us/sample - loss: 4.2336 - y1_output_loss: 0.8628 - y2_output_loss: 3.3674 - y1_output_root_mean_squared_error: 0.9273 - y2_output_root_mean_squared_error: 1.8368 - val_loss: 5.4750 - val_y1_output_loss: 2.2365 - val_y2_output_loss: 3.2211 - val_y1_output_root_mean_squared_error: 1.4964 - val_y2_output_root_mean_squared_error: 1.7988
# Epoch 46/500
# 614/614 [==============================] - 0s 101us/sample - loss: 3.5217 - y1_output_loss: 0.8692 - y2_output_loss: 2.6365 - y1_output_root_mean_squared_error: 0.9331 - y2_output_root_mean_squared_error: 1.6282 - val_loss: 4.7161 - val_y1_output_loss: 1.5975 - val_y2_output_loss: 2.9601 - val_y1_output_root_mean_squared_error: 1.2849 - val_y2_output_root_mean_squared_error: 1.7508
# Epoch 47/500
# 614/614 [==============================] - 0s 101us/sample - loss: 3.4644 - y1_output_loss: 0.7318 - y2_output_loss: 2.7229 - y1_output_root_mean_squared_error: 0.8587 - y2_output_root_mean_squared_error: 1.6514 - val_loss: 2.3821 - val_y1_output_loss: 0.4674 - val_y2_output_loss: 1.8476 - val_y1_output_root_mean_squared_error: 0.6956 - val_y2_output_root_mean_squared_error: 1.3778
# Epoch 48/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.3439 - y1_output_loss: 0.4929 - y2_output_loss: 1.8308 - y1_output_root_mean_squared_error: 0.7044 - y2_output_root_mean_squared_error: 1.3593 - val_loss: 3.1945 - val_y1_output_loss: 0.4507 - val_y2_output_loss: 2.6409 - val_y1_output_root_mean_squared_error: 0.6823 - val_y2_output_root_mean_squared_error: 1.6520
# Epoch 49/500
# 614/614 [==============================] - 0s 106us/sample - loss: 1.9810 - y1_output_loss: 0.4352 - y2_output_loss: 1.5576 - y1_output_root_mean_squared_error: 0.6582 - y2_output_root_mean_squared_error: 1.2441 - val_loss: 2.3215 - val_y1_output_loss: 0.4980 - val_y2_output_loss: 1.7604 - val_y1_output_root_mean_squared_error: 0.7088 - val_y2_output_root_mean_squared_error: 1.3487
# Epoch 50/500
# 614/614 [==============================] - 0s 104us/sample - loss: 2.4024 - y1_output_loss: 0.5436 - y2_output_loss: 1.8578 - y1_output_root_mean_squared_error: 0.7380 - y2_output_root_mean_squared_error: 1.3630 - val_loss: 2.6854 - val_y1_output_loss: 0.4834 - val_y2_output_loss: 2.1083 - val_y1_output_root_mean_squared_error: 0.7081 - val_y2_output_root_mean_squared_error: 1.4779
# Epoch 51/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.6533 - y1_output_loss: 0.5533 - y2_output_loss: 2.1016 - y1_output_root_mean_squared_error: 0.7447 - y2_output_root_mean_squared_error: 1.4487 - val_loss: 3.0028 - val_y1_output_loss: 0.8229 - val_y2_output_loss: 2.0790 - val_y1_output_root_mean_squared_error: 0.9242 - val_y2_output_root_mean_squared_error: 1.4658
# Epoch 52/500
# 614/614 [==============================] - 0s 104us/sample - loss: 3.6252 - y1_output_loss: 0.8392 - y2_output_loss: 2.7778 - y1_output_root_mean_squared_error: 0.9159 - y2_output_root_mean_squared_error: 1.6692 - val_loss: 2.2716 - val_y1_output_loss: 0.5088 - val_y2_output_loss: 1.6868 - val_y1_output_root_mean_squared_error: 0.7249 - val_y2_output_root_mean_squared_error: 1.3214
# Epoch 53/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.3506 - y1_output_loss: 0.5509 - y2_output_loss: 1.8477 - y1_output_root_mean_squared_error: 0.7237 - y2_output_root_mean_squared_error: 1.3516 - val_loss: 11.1217 - val_y1_output_loss: 4.0176 - val_y2_output_loss: 6.7414 - val_y1_output_root_mean_squared_error: 2.0382 - val_y2_output_root_mean_squared_error: 2.6396
# Epoch 54/500
# 614/614 [==============================] - 0s 103us/sample - loss: 3.4377 - y1_output_loss: 0.7873 - y2_output_loss: 2.6284 - y1_output_root_mean_squared_error: 0.8877 - y2_output_root_mean_squared_error: 1.6278 - val_loss: 2.5718 - val_y1_output_loss: 0.5529 - val_y2_output_loss: 1.9325 - val_y1_output_root_mean_squared_error: 0.7555 - val_y2_output_root_mean_squared_error: 1.4145
# Epoch 55/500
# 614/614 [==============================] - 0s 99us/sample - loss: 2.3356 - y1_output_loss: 0.5389 - y2_output_loss: 1.8236 - y1_output_root_mean_squared_error: 0.7254 - y2_output_root_mean_squared_error: 1.3451 - val_loss: 5.5787 - val_y1_output_loss: 1.5948 - val_y2_output_loss: 3.8322 - val_y1_output_root_mean_squared_error: 1.2838 - val_y2_output_root_mean_squared_error: 1.9826
# Epoch 56/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.8440 - y1_output_loss: 0.6588 - y2_output_loss: 2.1787 - y1_output_root_mean_squared_error: 0.8109 - y2_output_root_mean_squared_error: 1.4787 - val_loss: 5.1504 - val_y1_output_loss: 1.0988 - val_y2_output_loss: 3.9029 - val_y1_output_root_mean_squared_error: 1.0656 - val_y2_output_root_mean_squared_error: 2.0037
# Epoch 57/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.7232 - y1_output_loss: 0.5884 - y2_output_loss: 2.1131 - y1_output_root_mean_squared_error: 0.7694 - y2_output_root_mean_squared_error: 1.4599 - val_loss: 2.0088 - val_y1_output_loss: 0.4210 - val_y2_output_loss: 1.5375 - val_y1_output_root_mean_squared_error: 0.6565 - val_y2_output_root_mean_squared_error: 1.2561
# Epoch 58/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.2763 - y1_output_loss: 0.4176 - y2_output_loss: 1.8628 - y1_output_root_mean_squared_error: 0.6438 - y2_output_root_mean_squared_error: 1.3645 - val_loss: 2.7816 - val_y1_output_loss: 0.3284 - val_y2_output_loss: 2.3580 - val_y1_output_root_mean_squared_error: 0.5821 - val_y2_output_root_mean_squared_error: 1.5629
# Epoch 59/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.5586 - y1_output_loss: 0.4908 - y2_output_loss: 2.0568 - y1_output_root_mean_squared_error: 0.6991 - y2_output_root_mean_squared_error: 1.4387 - val_loss: 3.2209 - val_y1_output_loss: 0.6568 - val_y2_output_loss: 2.4568 - val_y1_output_root_mean_squared_error: 0.8241 - val_y2_output_root_mean_squared_error: 1.5943
# Epoch 60/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.3989 - y1_output_loss: 0.5186 - y2_output_loss: 1.8697 - y1_output_root_mean_squared_error: 0.7187 - y2_output_root_mean_squared_error: 1.3720 - val_loss: 2.6029 - val_y1_output_loss: 0.3919 - val_y2_output_loss: 2.1321 - val_y1_output_root_mean_squared_error: 0.6343 - val_y2_output_root_mean_squared_error: 1.4834
# Epoch 61/500
# 614/614 [==============================] - 0s 99us/sample - loss: 2.0894 - y1_output_loss: 0.4400 - y2_output_loss: 1.6783 - y1_output_root_mean_squared_error: 0.6645 - y2_output_root_mean_squared_error: 1.2837 - val_loss: 4.0662 - val_y1_output_loss: 0.5121 - val_y2_output_loss: 3.4233 - val_y1_output_root_mean_squared_error: 0.7276 - val_y2_output_root_mean_squared_error: 1.8806
# Epoch 62/500
# 614/614 [==============================] - 0s 103us/sample - loss: 3.2895 - y1_output_loss: 0.7086 - y2_output_loss: 2.5561 - y1_output_root_mean_squared_error: 0.8457 - y2_output_root_mean_squared_error: 1.6044 - val_loss: 2.4844 - val_y1_output_loss: 0.2895 - val_y2_output_loss: 2.1118 - val_y1_output_root_mean_squared_error: 0.5441 - val_y2_output_root_mean_squared_error: 1.4793
# Epoch 63/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.3288 - y1_output_loss: 0.4924 - y2_output_loss: 1.8246 - y1_output_root_mean_squared_error: 0.6992 - y2_output_root_mean_squared_error: 1.3564 - val_loss: 2.7101 - val_y1_output_loss: 0.6784 - val_y2_output_loss: 1.9682 - val_y1_output_root_mean_squared_error: 0.8281 - val_y2_output_root_mean_squared_error: 1.4228
# Epoch 64/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.8664 - y1_output_loss: 0.6239 - y2_output_loss: 2.2310 - y1_output_root_mean_squared_error: 0.7870 - y2_output_root_mean_squared_error: 1.4990 - val_loss: 2.4791 - val_y1_output_loss: 0.6712 - val_y2_output_loss: 1.7342 - val_y1_output_root_mean_squared_error: 0.8327 - val_y2_output_root_mean_squared_error: 1.3363
# Epoch 65/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.7955 - y1_output_loss: 0.5848 - y2_output_loss: 2.2379 - y1_output_root_mean_squared_error: 0.7583 - y2_output_root_mean_squared_error: 1.4901 - val_loss: 8.6046 - val_y1_output_loss: 2.4545 - val_y2_output_loss: 5.9670 - val_y1_output_root_mean_squared_error: 1.5856 - val_y2_output_root_mean_squared_error: 2.4679
# Epoch 66/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.5058 - y1_output_loss: 0.6099 - y2_output_loss: 1.8905 - y1_output_root_mean_squared_error: 0.7794 - y2_output_root_mean_squared_error: 1.3778 - val_loss: 4.3324 - val_y1_output_loss: 1.6895 - val_y2_output_loss: 2.4897 - val_y1_output_root_mean_squared_error: 1.3223 - val_y2_output_root_mean_squared_error: 1.6075
# Epoch 67/500
# 614/614 [==============================] - 0s 101us/sample - loss: 3.9498 - y1_output_loss: 0.9437 - y2_output_loss: 2.9810 - y1_output_root_mean_squared_error: 0.9747 - y2_output_root_mean_squared_error: 1.7320 - val_loss: 3.1619 - val_y1_output_loss: 0.5929 - val_y2_output_loss: 2.4599 - val_y1_output_root_mean_squared_error: 0.7810 - val_y2_output_root_mean_squared_error: 1.5975
# Epoch 68/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.3729 - y1_output_loss: 0.5012 - y2_output_loss: 1.8548 - y1_output_root_mean_squared_error: 0.7108 - y2_output_root_mean_squared_error: 1.3666 - val_loss: 2.2536 - val_y1_output_loss: 0.3892 - val_y2_output_loss: 1.7924 - val_y1_output_root_mean_squared_error: 0.6351 - val_y2_output_root_mean_squared_error: 1.3602
# Epoch 69/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.5356 - y1_output_loss: 0.4754 - y2_output_loss: 2.0584 - y1_output_root_mean_squared_error: 0.6877 - y2_output_root_mean_squared_error: 1.4362 - val_loss: 2.0955 - val_y1_output_loss: 0.3546 - val_y2_output_loss: 1.6680 - val_y1_output_root_mean_squared_error: 0.6061 - val_y2_output_root_mean_squared_error: 1.3146
# Epoch 70/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.1536 - y1_output_loss: 0.4236 - y2_output_loss: 1.7523 - y1_output_root_mean_squared_error: 0.6511 - y2_output_root_mean_squared_error: 1.3152 - val_loss: 5.3627 - val_y1_output_loss: 0.6600 - val_y2_output_loss: 4.5283 - val_y1_output_root_mean_squared_error: 0.8258 - val_y2_output_root_mean_squared_error: 2.1635
# Epoch 71/500
# 614/614 [==============================] - 0s 104us/sample - loss: 2.4091 - y1_output_loss: 0.5566 - y2_output_loss: 1.8524 - y1_output_root_mean_squared_error: 0.7449 - y2_output_root_mean_squared_error: 1.3617 - val_loss: 2.0450 - val_y1_output_loss: 0.4082 - val_y2_output_loss: 1.5812 - val_y1_output_root_mean_squared_error: 0.6461 - val_y2_output_root_mean_squared_error: 1.2757
# Epoch 72/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.9447 - y1_output_loss: 0.6962 - y2_output_loss: 2.3223 - y1_output_root_mean_squared_error: 0.8104 - y2_output_root_mean_squared_error: 1.5126 - val_loss: 12.5458 - val_y1_output_loss: 3.0822 - val_y2_output_loss: 9.0169 - val_y1_output_root_mean_squared_error: 1.7862 - val_y2_output_root_mean_squared_error: 3.0586
# Epoch 73/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.3622 - y1_output_loss: 0.5883 - y2_output_loss: 1.7608 - y1_output_root_mean_squared_error: 0.7681 - y2_output_root_mean_squared_error: 1.3313 - val_loss: 2.5066 - val_y1_output_loss: 0.6233 - val_y2_output_loss: 1.8096 - val_y1_output_root_mean_squared_error: 0.8028 - val_y2_output_root_mean_squared_error: 1.3646
# Epoch 74/500
# 614/614 [==============================] - 0s 104us/sample - loss: 1.8568 - y1_output_loss: 0.3827 - y2_output_loss: 1.4712 - y1_output_root_mean_squared_error: 0.6183 - y2_output_root_mean_squared_error: 1.2143 - val_loss: 2.4849 - val_y1_output_loss: 0.6445 - val_y2_output_loss: 1.7576 - val_y1_output_root_mean_squared_error: 0.8172 - val_y2_output_root_mean_squared_error: 1.3480
# Epoch 75/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.6916 - y1_output_loss: 0.6661 - y2_output_loss: 2.0148 - y1_output_root_mean_squared_error: 0.8191 - y2_output_root_mean_squared_error: 1.4215 - val_loss: 1.9343 - val_y1_output_loss: 0.5217 - val_y2_output_loss: 1.3728 - val_y1_output_root_mean_squared_error: 0.7329 - val_y2_output_root_mean_squared_error: 1.1820
# Epoch 76/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.8899 - y1_output_loss: 0.3877 - y2_output_loss: 1.5353 - y1_output_root_mean_squared_error: 0.6212 - y2_output_root_mean_squared_error: 1.2264 - val_loss: 1.9727 - val_y1_output_loss: 0.5029 - val_y2_output_loss: 1.4091 - val_y1_output_root_mean_squared_error: 0.7214 - val_y2_output_root_mean_squared_error: 1.2051
# Epoch 77/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.6419 - y1_output_loss: 0.5847 - y2_output_loss: 2.0376 - y1_output_root_mean_squared_error: 0.7660 - y2_output_root_mean_squared_error: 1.4336 - val_loss: 1.9913 - val_y1_output_loss: 0.4213 - val_y2_output_loss: 1.5093 - val_y1_output_root_mean_squared_error: 0.6602 - val_y2_output_root_mean_squared_error: 1.2472
# Epoch 78/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.9305 - y1_output_loss: 0.3299 - y2_output_loss: 1.7025 - y1_output_root_mean_squared_error: 0.5755 - y2_output_root_mean_squared_error: 1.2646 - val_loss: 32.9647 - val_y1_output_loss: 1.6889 - val_y2_output_loss: 30.2723 - val_y1_output_root_mean_squared_error: 1.3237 - val_y2_output_root_mean_squared_error: 5.5868
# Epoch 79/500
# 614/614 [==============================] - 0s 99us/sample - loss: 2.5783 - y1_output_loss: 0.4635 - y2_output_loss: 2.1198 - y1_output_root_mean_squared_error: 0.6835 - y2_output_root_mean_squared_error: 1.4530 - val_loss: 6.6369 - val_y1_output_loss: 0.5385 - val_y2_output_loss: 5.9030 - val_y1_output_root_mean_squared_error: 0.7473 - val_y2_output_root_mean_squared_error: 2.4654
# Epoch 80/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.9454 - y1_output_loss: 0.3917 - y2_output_loss: 1.5678 - y1_output_root_mean_squared_error: 0.6260 - y2_output_root_mean_squared_error: 1.2464 - val_loss: 3.5319 - val_y1_output_loss: 0.8548 - val_y2_output_loss: 2.5808 - val_y1_output_root_mean_squared_error: 0.9330 - val_y2_output_root_mean_squared_error: 1.6314
# Epoch 81/500
# 614/614 [==============================] - 0s 104us/sample - loss: 1.7456 - y1_output_loss: 0.3435 - y2_output_loss: 1.3975 - y1_output_root_mean_squared_error: 0.5870 - y2_output_root_mean_squared_error: 1.1837 - val_loss: 2.8630 - val_y1_output_loss: 0.2913 - val_y2_output_loss: 2.4863 - val_y1_output_root_mean_squared_error: 0.5486 - val_y2_output_root_mean_squared_error: 1.6006
# Epoch 82/500
# 614/614 [==============================] - 0s 99us/sample - loss: 1.8250 - y1_output_loss: 0.3866 - y2_output_loss: 1.4536 - y1_output_root_mean_squared_error: 0.6247 - y2_output_root_mean_squared_error: 1.1978 - val_loss: 3.7206 - val_y1_output_loss: 0.3205 - val_y2_output_loss: 3.3004 - val_y1_output_root_mean_squared_error: 0.5746 - val_y2_output_root_mean_squared_error: 1.8413
# Epoch 83/500
# 614/614 [==============================] - 0s 99us/sample - loss: 2.4303 - y1_output_loss: 0.4325 - y2_output_loss: 1.9860 - y1_output_root_mean_squared_error: 0.6583 - y2_output_root_mean_squared_error: 1.4131 - val_loss: 2.8892 - val_y1_output_loss: 0.5378 - val_y2_output_loss: 2.2758 - val_y1_output_root_mean_squared_error: 0.7471 - val_y2_output_root_mean_squared_error: 1.5268
# Epoch 84/500
# 614/614 [==============================] - 0s 106us/sample - loss: 2.9727 - y1_output_loss: 0.6659 - y2_output_loss: 2.3702 - y1_output_root_mean_squared_error: 0.8174 - y2_output_root_mean_squared_error: 1.5181 - val_loss: 7.7987 - val_y1_output_loss: 1.2290 - val_y2_output_loss: 6.3130 - val_y1_output_root_mean_squared_error: 1.1278 - val_y2_output_root_mean_squared_error: 2.5547
# Epoch 85/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.9956 - y1_output_loss: 0.3922 - y2_output_loss: 1.5915 - y1_output_root_mean_squared_error: 0.6291 - y2_output_root_mean_squared_error: 1.2648 - val_loss: 1.8881 - val_y1_output_loss: 0.3179 - val_y2_output_loss: 1.5082 - val_y1_output_root_mean_squared_error: 0.5716 - val_y2_output_root_mean_squared_error: 1.2496
# Epoch 86/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.8634 - y1_output_loss: 0.4515 - y2_output_loss: 1.4144 - y1_output_root_mean_squared_error: 0.6697 - y2_output_root_mean_squared_error: 1.1895 - val_loss: 2.1488 - val_y1_output_loss: 0.3963 - val_y2_output_loss: 1.6930 - val_y1_output_root_mean_squared_error: 0.6408 - val_y2_output_root_mean_squared_error: 1.3184
# Epoch 87/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.6802 - y1_output_loss: 0.3018 - y2_output_loss: 1.3707 - y1_output_root_mean_squared_error: 0.5491 - y2_output_root_mean_squared_error: 1.1742 - val_loss: 1.8003 - val_y1_output_loss: 0.3255 - val_y2_output_loss: 1.4289 - val_y1_output_root_mean_squared_error: 0.5796 - val_y2_output_root_mean_squared_error: 1.2101
# Epoch 88/500
# 614/614 [==============================] - 0s 99us/sample - loss: 1.6719 - y1_output_loss: 0.3530 - y2_output_loss: 1.3493 - y1_output_root_mean_squared_error: 0.5932 - y2_output_root_mean_squared_error: 1.1489 - val_loss: 5.0474 - val_y1_output_loss: 0.5879 - val_y2_output_loss: 4.2860 - val_y1_output_root_mean_squared_error: 0.7812 - val_y2_output_root_mean_squared_error: 2.1065
# Epoch 89/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.4144 - y1_output_loss: 0.4047 - y2_output_loss: 2.0504 - y1_output_root_mean_squared_error: 0.6354 - y2_output_root_mean_squared_error: 1.4180 - val_loss: 4.2619 - val_y1_output_loss: 1.0126 - val_y2_output_loss: 3.0989 - val_y1_output_root_mean_squared_error: 1.0238 - val_y2_output_root_mean_squared_error: 1.7927
# Epoch 90/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.9666 - y1_output_loss: 0.4176 - y2_output_loss: 1.5381 - y1_output_root_mean_squared_error: 0.6448 - y2_output_root_mean_squared_error: 1.2453 - val_loss: 1.8977 - val_y1_output_loss: 0.3358 - val_y2_output_loss: 1.4953 - val_y1_output_root_mean_squared_error: 0.5899 - val_y2_output_root_mean_squared_error: 1.2449
# Epoch 91/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.0086 - y1_output_loss: 0.4117 - y2_output_loss: 1.7537 - y1_output_root_mean_squared_error: 0.6035 - y2_output_root_mean_squared_error: 1.2823 - val_loss: 40.7936 - val_y1_output_loss: 9.7460 - val_y2_output_loss: 29.6892 - val_y1_output_root_mean_squared_error: 3.1777 - val_y2_output_root_mean_squared_error: 5.5404
# Epoch 92/500
# 614/614 [==============================] - 0s 107us/sample - loss: 2.8901 - y1_output_loss: 0.5001 - y2_output_loss: 2.3680 - y1_output_root_mean_squared_error: 0.7092 - y2_output_root_mean_squared_error: 1.5450 - val_loss: 1.6977 - val_y1_output_loss: 0.2709 - val_y2_output_loss: 1.3761 - val_y1_output_root_mean_squared_error: 0.5266 - val_y2_output_root_mean_squared_error: 1.1918
# Epoch 93/500
# 614/614 [==============================] - 0s 109us/sample - loss: 1.7238 - y1_output_loss: 0.3864 - y2_output_loss: 1.3284 - y1_output_root_mean_squared_error: 0.6239 - y2_output_root_mean_squared_error: 1.1552 - val_loss: 2.0670 - val_y1_output_loss: 0.4615 - val_y2_output_loss: 1.5374 - val_y1_output_root_mean_squared_error: 0.6910 - val_y2_output_root_mean_squared_error: 1.2607
# Epoch 94/500
# 614/614 [==============================] - 0s 104us/sample - loss: 1.8414 - y1_output_loss: 0.4236 - y2_output_loss: 1.4139 - y1_output_root_mean_squared_error: 0.6494 - y2_output_root_mean_squared_error: 1.1915 - val_loss: 3.1097 - val_y1_output_loss: 0.7265 - val_y2_output_loss: 2.2796 - val_y1_output_root_mean_squared_error: 0.8669 - val_y2_output_root_mean_squared_error: 1.5357
# Epoch 95/500
# 614/614 [==============================] - 0s 104us/sample - loss: 1.4812 - y1_output_loss: 0.3390 - y2_output_loss: 1.1406 - y1_output_root_mean_squared_error: 0.5810 - y2_output_root_mean_squared_error: 1.0694 - val_loss: 1.5849 - val_y1_output_loss: 0.3331 - val_y2_output_loss: 1.2070 - val_y1_output_root_mean_squared_error: 0.5869 - val_y2_output_root_mean_squared_error: 1.1137
# Epoch 96/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.9331 - y1_output_loss: 0.4499 - y2_output_loss: 1.4795 - y1_output_root_mean_squared_error: 0.6707 - y2_output_root_mean_squared_error: 1.2179 - val_loss: 2.3615 - val_y1_output_loss: 0.3121 - val_y2_output_loss: 1.9803 - val_y1_output_root_mean_squared_error: 0.5676 - val_y2_output_root_mean_squared_error: 1.4281
# Epoch 97/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.6873 - y1_output_loss: 0.3042 - y2_output_loss: 1.3691 - y1_output_root_mean_squared_error: 0.5534 - y2_output_root_mean_squared_error: 1.1752 - val_loss: 2.0147 - val_y1_output_loss: 0.4694 - val_y2_output_loss: 1.5118 - val_y1_output_root_mean_squared_error: 0.6933 - val_y2_output_root_mean_squared_error: 1.2386
# Epoch 98/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.6629 - y1_output_loss: 0.3171 - y2_output_loss: 1.3587 - y1_output_root_mean_squared_error: 0.5654 - y2_output_root_mean_squared_error: 1.1590 - val_loss: 2.6920 - val_y1_output_loss: 0.3691 - val_y2_output_loss: 2.2784 - val_y1_output_root_mean_squared_error: 0.6133 - val_y2_output_root_mean_squared_error: 1.5218
# Epoch 99/500
# 614/614 [==============================] - 0s 99us/sample - loss: 1.5619 - y1_output_loss: 0.3161 - y2_output_loss: 1.2361 - y1_output_root_mean_squared_error: 0.5644 - y2_output_root_mean_squared_error: 1.1151 - val_loss: 1.9198 - val_y1_output_loss: 0.3229 - val_y2_output_loss: 1.5451 - val_y1_output_root_mean_squared_error: 0.5785 - val_y2_output_root_mean_squared_error: 1.2590
# Epoch 100/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.2780 - y1_output_loss: 0.3908 - y2_output_loss: 1.8836 - y1_output_root_mean_squared_error: 0.6252 - y2_output_root_mean_squared_error: 1.3738 - val_loss: 3.4297 - val_y1_output_loss: 0.3664 - val_y2_output_loss: 2.9659 - val_y1_output_root_mean_squared_error: 0.6114 - val_y2_output_root_mean_squared_error: 1.7481
# Epoch 101/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.7377 - y1_output_loss: 0.3810 - y2_output_loss: 1.3684 - y1_output_root_mean_squared_error: 0.6155 - y2_output_root_mean_squared_error: 1.1657 - val_loss: 6.5008 - val_y1_output_loss: 0.7722 - val_y2_output_loss: 5.6314 - val_y1_output_root_mean_squared_error: 0.8864 - val_y2_output_root_mean_squared_error: 2.3906
# Epoch 102/500
# 614/614 [==============================] - 0s 104us/sample - loss: 3.3853 - y1_output_loss: 0.8770 - y2_output_loss: 2.5009 - y1_output_root_mean_squared_error: 0.9397 - y2_output_root_mean_squared_error: 1.5818 - val_loss: 3.7326 - val_y1_output_loss: 0.5178 - val_y2_output_loss: 3.0897 - val_y1_output_root_mean_squared_error: 0.7323 - val_y2_output_root_mean_squared_error: 1.7878
# Epoch 103/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.9031 - y1_output_loss: 0.3653 - y2_output_loss: 1.5797 - y1_output_root_mean_squared_error: 0.5968 - y2_output_root_mean_squared_error: 1.2438 - val_loss: 2.6377 - val_y1_output_loss: 0.8334 - val_y2_output_loss: 1.7594 - val_y1_output_root_mean_squared_error: 0.9271 - val_y2_output_root_mean_squared_error: 1.3335
# Epoch 104/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.6297 - y1_output_loss: 0.3380 - y2_output_loss: 1.2840 - y1_output_root_mean_squared_error: 0.5834 - y2_output_root_mean_squared_error: 1.1355 - val_loss: 1.8090 - val_y1_output_loss: 0.4749 - val_y2_output_loss: 1.2771 - val_y1_output_root_mean_squared_error: 0.6993 - val_y2_output_root_mean_squared_error: 1.1489
# Epoch 105/500
# 614/614 [==============================] - 0s 119us/sample - loss: 3.3116 - y1_output_loss: 0.8903 - y2_output_loss: 2.4088 - y1_output_root_mean_squared_error: 0.9427 - y2_output_root_mean_squared_error: 1.5566 - val_loss: 2.1698 - val_y1_output_loss: 0.5311 - val_y2_output_loss: 1.5657 - val_y1_output_root_mean_squared_error: 0.7421 - val_y2_output_root_mean_squared_error: 1.2724
# Epoch 106/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.1563 - y1_output_loss: 0.4863 - y2_output_loss: 1.6579 - y1_output_root_mean_squared_error: 0.7006 - y2_output_root_mean_squared_error: 1.2905 - val_loss: 2.2535 - val_y1_output_loss: 0.5425 - val_y2_output_loss: 1.6422 - val_y1_output_root_mean_squared_error: 0.7500 - val_y2_output_root_mean_squared_error: 1.3004
# Epoch 107/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.5487 - y1_output_loss: 0.4940 - y2_output_loss: 2.0878 - y1_output_root_mean_squared_error: 0.6941 - y2_output_root_mean_squared_error: 1.4377 - val_loss: 15.8190 - val_y1_output_loss: 4.2331 - val_y2_output_loss: 11.0669 - val_y1_output_root_mean_squared_error: 2.0964 - val_y2_output_root_mean_squared_error: 3.3800
# Epoch 108/500
# 614/614 [==============================] - 0s 101us/sample - loss: 2.3307 - y1_output_loss: 0.4977 - y2_output_loss: 1.8219 - y1_output_root_mean_squared_error: 0.7067 - y2_output_root_mean_squared_error: 1.3533 - val_loss: 2.5669 - val_y1_output_loss: 0.3990 - val_y2_output_loss: 2.0820 - val_y1_output_root_mean_squared_error: 0.6407 - val_y2_output_root_mean_squared_error: 1.4685
# Epoch 109/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.3841 - y1_output_loss: 0.2611 - y2_output_loss: 1.1147 - y1_output_root_mean_squared_error: 0.5112 - y2_output_root_mean_squared_error: 1.0596 - val_loss: 1.9351 - val_y1_output_loss: 0.2731 - val_y2_output_loss: 1.6119 - val_y1_output_root_mean_squared_error: 0.5308 - val_y2_output_root_mean_squared_error: 1.2858
# Epoch 110/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.6283 - y1_output_loss: 0.3374 - y2_output_loss: 1.2916 - y1_output_root_mean_squared_error: 0.5812 - y2_output_root_mean_squared_error: 1.1360 - val_loss: 3.1763 - val_y1_output_loss: 0.6017 - val_y2_output_loss: 2.4739 - val_y1_output_root_mean_squared_error: 0.7898 - val_y2_output_root_mean_squared_error: 1.5977
# Epoch 111/500
# 614/614 [==============================] - 0s 104us/sample - loss: 1.4857 - y1_output_loss: 0.3244 - y2_output_loss: 1.2340 - y1_output_root_mean_squared_error: 0.5692 - y2_output_root_mean_squared_error: 1.0778 - val_loss: 15.9323 - val_y1_output_loss: 1.2484 - val_y2_output_loss: 14.1504 - val_y1_output_root_mean_squared_error: 1.1356 - val_y2_output_root_mean_squared_error: 3.8266
# Epoch 112/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.8380 - y1_output_loss: 0.3436 - y2_output_loss: 1.4957 - y1_output_root_mean_squared_error: 0.5887 - y2_output_root_mean_squared_error: 1.2212 - val_loss: 2.1161 - val_y1_output_loss: 0.4273 - val_y2_output_loss: 1.6217 - val_y1_output_root_mean_squared_error: 0.6637 - val_y2_output_root_mean_squared_error: 1.2944
# Epoch 113/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.7030 - y1_output_loss: 0.3028 - y2_output_loss: 1.4021 - y1_output_root_mean_squared_error: 0.5494 - y2_output_root_mean_squared_error: 1.1837 - val_loss: 2.0568 - val_y1_output_loss: 0.2530 - val_y2_output_loss: 1.7370 - val_y1_output_root_mean_squared_error: 0.5117 - val_y2_output_root_mean_squared_error: 1.3398
# Epoch 114/500
# 614/614 [==============================] - 0s 109us/sample - loss: 1.6701 - y1_output_loss: 0.3097 - y2_output_loss: 1.3619 - y1_output_root_mean_squared_error: 0.5541 - y2_output_root_mean_squared_error: 1.1675 - val_loss: 1.8630 - val_y1_output_loss: 0.4995 - val_y2_output_loss: 1.3049 - val_y1_output_root_mean_squared_error: 0.7198 - val_y2_output_root_mean_squared_error: 1.1597
# Epoch 115/500
# 614/614 [==============================] - 0s 104us/sample - loss: 1.3113 - y1_output_loss: 0.2509 - y2_output_loss: 1.0545 - y1_output_root_mean_squared_error: 0.5030 - y2_output_root_mean_squared_error: 1.0287 - val_loss: 1.5232 - val_y1_output_loss: 0.2999 - val_y2_output_loss: 1.1803 - val_y1_output_root_mean_squared_error: 0.5562 - val_y2_output_root_mean_squared_error: 1.1017
# Epoch 116/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.5209 - y1_output_loss: 0.2626 - y2_output_loss: 1.2458 - y1_output_root_mean_squared_error: 0.5148 - y2_output_root_mean_squared_error: 1.1207 - val_loss: 1.4878 - val_y1_output_loss: 0.3043 - val_y2_output_loss: 1.1372 - val_y1_output_root_mean_squared_error: 0.5588 - val_y2_output_root_mean_squared_error: 1.0842
# Epoch 117/500
# 614/614 [==============================] - 0s 103us/sample - loss: 2.4272 - y1_output_loss: 0.4979 - y2_output_loss: 1.9174 - y1_output_root_mean_squared_error: 0.7083 - y2_output_root_mean_squared_error: 1.3876 - val_loss: 2.6310 - val_y1_output_loss: 0.5430 - val_y2_output_loss: 2.0159 - val_y1_output_root_mean_squared_error: 0.7429 - val_y2_output_root_mean_squared_error: 1.4419
# Epoch 118/500
# 614/614 [==============================] - 0s 103us/sample - loss: 1.5111 - y1_output_loss: 0.2990 - y2_output_loss: 1.2005 - y1_output_root_mean_squared_error: 0.5489 - y2_output_root_mean_squared_error: 1.0999 - val_loss: 1.6513 - val_y1_output_loss: 0.3201 - val_y2_output_loss: 1.2875 - val_y1_output_root_mean_squared_error: 0.5707 - val_y2_output_root_mean_squared_error: 1.1514
# Epoch 119/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.6982 - y1_output_loss: 0.3381 - y2_output_loss: 1.3553 - y1_output_root_mean_squared_error: 0.5837 - y2_output_root_mean_squared_error: 1.1651 - val_loss: 3.4233 - val_y1_output_loss: 0.2760 - val_y2_output_loss: 3.0581 - val_y1_output_root_mean_squared_error: 0.5335 - val_y2_output_root_mean_squared_error: 1.7716
# Epoch 120/500
# 614/614 [==============================] - 0s 101us/sample - loss: 1.6182 - y1_output_loss: 0.3391 - y2_output_loss: 1.2897 - y1_output_root_mean_squared_error: 0.5786 - y2_output_root_mean_squared_error: 1.1329 - val_loss: 4.1256 - val_y1_output_loss: 0.7079 - val_y2_output_loss: 3.3131 - val_y1_output_root_mean_squared_error: 0.8499 - val_y2_output_root_mean_squared_error: 1.8448
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3450 - y1_output_loss: 0.1033 - y2_output_loss: 0.2405 - y1_output_root_mean_squared_error: 0.3225 - y2_output_root_mean_squared_error: 0.4909 - val_loss: 0.8431 - val_y1_output_loss: 0.1959 - val_y2_output_loss: 0.6337 - val_y1_output_root_mean_squared_error: 0.4487 - val_y2_output_root_mean_squared_error: 0.8011
# Epoch 462/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3410 - y1_output_loss: 0.1060 - y2_output_loss: 0.2343 - y1_output_root_mean_squared_error: 0.3245 - y2_output_root_mean_squared_error: 0.4855 - val_loss: 0.7755 - val_y1_output_loss: 0.1949 - val_y2_output_loss: 0.5744 - val_y1_output_root_mean_squared_error: 0.4449 - val_y2_output_root_mean_squared_error: 0.7600
# Epoch 463/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.4272 - y1_output_loss: 0.1162 - y2_output_loss: 0.3076 - y1_output_root_mean_squared_error: 0.3420 - y2_output_root_mean_squared_error: 0.5570 - val_loss: 0.9062 - val_y1_output_loss: 0.2219 - val_y2_output_loss: 0.6652 - val_y1_output_root_mean_squared_error: 0.4735 - val_y2_output_root_mean_squared_error: 0.8259
# Epoch 464/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.3441 - y1_output_loss: 0.1089 - y2_output_loss: 0.2378 - y1_output_root_mean_squared_error: 0.3269 - y2_output_root_mean_squared_error: 0.4870 - val_loss: 1.4029 - val_y1_output_loss: 0.4501 - val_y2_output_loss: 0.9159 - val_y1_output_root_mean_squared_error: 0.6802 - val_y2_output_root_mean_squared_error: 0.9697
# Epoch 465/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.4521 - y1_output_loss: 0.1281 - y2_output_loss: 0.3254 - y1_output_root_mean_squared_error: 0.3573 - y2_output_root_mean_squared_error: 0.5696 - val_loss: 0.9714 - val_y1_output_loss: 0.2619 - val_y2_output_loss: 0.6864 - val_y1_output_root_mean_squared_error: 0.5194 - val_y2_output_root_mean_squared_error: 0.8376
# Epoch 466/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.3380 - y1_output_loss: 0.1026 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3215 - y2_output_root_mean_squared_error: 0.4844 - val_loss: 0.8907 - val_y1_output_loss: 0.2079 - val_y2_output_loss: 0.6650 - val_y1_output_root_mean_squared_error: 0.4637 - val_y2_output_root_mean_squared_error: 0.8220
# Epoch 467/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.4516 - y1_output_loss: 0.1277 - y2_output_loss: 0.3452 - y1_output_root_mean_squared_error: 0.3538 - y2_output_root_mean_squared_error: 0.5713 - val_loss: 1.8817 - val_y1_output_loss: 0.2995 - val_y2_output_loss: 1.5329 - val_y1_output_root_mean_squared_error: 0.5499 - val_y2_output_root_mean_squared_error: 1.2567
# Epoch 468/500
# 614/614 [==============================] - 0s 99us/sample - loss: 0.4320 - y1_output_loss: 0.1315 - y2_output_loss: 0.2993 - y1_output_root_mean_squared_error: 0.3625 - y2_output_root_mean_squared_error: 0.5482 - val_loss: 1.1456 - val_y1_output_loss: 0.3275 - val_y2_output_loss: 0.7888 - val_y1_output_root_mean_squared_error: 0.5790 - val_y2_output_root_mean_squared_error: 0.9002
# Epoch 469/500
# 614/614 [==============================] - 0s 99us/sample - loss: 0.3072 - y1_output_loss: 0.1018 - y2_output_loss: 0.2045 - y1_output_root_mean_squared_error: 0.3204 - y2_output_root_mean_squared_error: 0.4523 - val_loss: 0.8495 - val_y1_output_loss: 0.1873 - val_y2_output_loss: 0.6464 - val_y1_output_root_mean_squared_error: 0.4396 - val_y2_output_root_mean_squared_error: 0.8101
# Epoch 470/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3239 - y1_output_loss: 0.0965 - y2_output_loss: 0.2283 - y1_output_root_mean_squared_error: 0.3097 - y2_output_root_mean_squared_error: 0.4775 - val_loss: 1.0372 - val_y1_output_loss: 0.3783 - val_y2_output_loss: 0.6323 - val_y1_output_root_mean_squared_error: 0.6254 - val_y2_output_root_mean_squared_error: 0.8038
# Epoch 471/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3218 - y1_output_loss: 0.1114 - y2_output_loss: 0.2094 - y1_output_root_mean_squared_error: 0.3343 - y2_output_root_mean_squared_error: 0.4583 - val_loss: 0.8593 - val_y1_output_loss: 0.2040 - val_y2_output_loss: 0.6412 - val_y1_output_root_mean_squared_error: 0.4594 - val_y2_output_root_mean_squared_error: 0.8052
# Epoch 472/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3957 - y1_output_loss: 0.1169 - y2_output_loss: 0.2771 - y1_output_root_mean_squared_error: 0.3432 - y2_output_root_mean_squared_error: 0.5272 - val_loss: 0.7644 - val_y1_output_loss: 0.1831 - val_y2_output_loss: 0.5732 - val_y1_output_root_mean_squared_error: 0.4341 - val_y2_output_root_mean_squared_error: 0.7589
# Epoch 473/500
# 614/614 [==============================] - 0s 103us/sample - loss: 0.2985 - y1_output_loss: 0.0969 - y2_output_loss: 0.1995 - y1_output_root_mean_squared_error: 0.3125 - y2_output_root_mean_squared_error: 0.4482 - val_loss: 0.8902 - val_y1_output_loss: 0.1750 - val_y2_output_loss: 0.6979 - val_y1_output_root_mean_squared_error: 0.4237 - val_y2_output_root_mean_squared_error: 0.8430
# Epoch 474/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3825 - y1_output_loss: 0.1184 - y2_output_loss: 0.2722 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.5210 - val_loss: 4.0004 - val_y1_output_loss: 1.5180 - val_y2_output_loss: 2.3675 - val_y1_output_root_mean_squared_error: 1.2546 - val_y2_output_root_mean_squared_error: 1.5577
# Epoch 475/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.4428 - y1_output_loss: 0.1498 - y2_output_loss: 0.2892 - y1_output_root_mean_squared_error: 0.3885 - y2_output_root_mean_squared_error: 0.5403 - val_loss: 0.7917 - val_y1_output_loss: 0.1940 - val_y2_output_loss: 0.5797 - val_y1_output_root_mean_squared_error: 0.4477 - val_y2_output_root_mean_squared_error: 0.7689
# Epoch 476/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.4285 - y1_output_loss: 0.1246 - y2_output_loss: 0.3016 - y1_output_root_mean_squared_error: 0.3545 - y2_output_root_mean_squared_error: 0.5503 - val_loss: 0.8607 - val_y1_output_loss: 0.1997 - val_y2_output_loss: 0.6452 - val_y1_output_root_mean_squared_error: 0.4520 - val_y2_output_root_mean_squared_error: 0.8102
# Epoch 477/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3052 - y1_output_loss: 0.0882 - y2_output_loss: 0.2194 - y1_output_root_mean_squared_error: 0.2980 - y2_output_root_mean_squared_error: 0.4652 - val_loss: 1.6205 - val_y1_output_loss: 0.2445 - val_y2_output_loss: 1.3370 - val_y1_output_root_mean_squared_error: 0.4991 - val_y2_output_root_mean_squared_error: 1.1711
# Epoch 478/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.4545 - y1_output_loss: 0.1138 - y2_output_loss: 0.3390 - y1_output_root_mean_squared_error: 0.3374 - y2_output_root_mean_squared_error: 0.5837 - val_loss: 0.7387 - val_y1_output_loss: 0.1755 - val_y2_output_loss: 0.5464 - val_y1_output_root_mean_squared_error: 0.4250 - val_y2_output_root_mean_squared_error: 0.7470
# Epoch 479/500
# 614/614 [==============================] - 0s 103us/sample - loss: 0.2717 - y1_output_loss: 0.0980 - y2_output_loss: 0.1741 - y1_output_root_mean_squared_error: 0.3137 - y2_output_root_mean_squared_error: 0.4163 - val_loss: 1.4840 - val_y1_output_loss: 0.2556 - val_y2_output_loss: 1.1954 - val_y1_output_root_mean_squared_error: 0.5138 - val_y2_output_root_mean_squared_error: 1.1045
# Epoch 480/500
# 614/614 [==============================] - 0s 107us/sample - loss: 0.3004 - y1_output_loss: 0.1051 - y2_output_loss: 0.1941 - y1_output_root_mean_squared_error: 0.3241 - y2_output_root_mean_squared_error: 0.4420 - val_loss: 0.8610 - val_y1_output_loss: 0.2082 - val_y2_output_loss: 0.6372 - val_y1_output_root_mean_squared_error: 0.4619 - val_y2_output_root_mean_squared_error: 0.8047
# Epoch 481/500
# 614/614 [==============================] - 0s 106us/sample - loss: 0.3440 - y1_output_loss: 0.1039 - y2_output_loss: 0.2402 - y1_output_root_mean_squared_error: 0.3237 - y2_output_root_mean_squared_error: 0.4891 - val_loss: 0.7662 - val_y1_output_loss: 0.1642 - val_y2_output_loss: 0.5867 - val_y1_output_root_mean_squared_error: 0.4105 - val_y2_output_root_mean_squared_error: 0.7731
# Epoch 482/500
# 614/614 [==============================] - 0s 107us/sample - loss: 0.4268 - y1_output_loss: 0.1134 - y2_output_loss: 0.3113 - y1_output_root_mean_squared_error: 0.3369 - y2_output_root_mean_squared_error: 0.5598 - val_loss: 0.8747 - val_y1_output_loss: 0.1934 - val_y2_output_loss: 0.6683 - val_y1_output_root_mean_squared_error: 0.4461 - val_y2_output_root_mean_squared_error: 0.8220
# Epoch 483/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.3390 - y1_output_loss: 0.1108 - y2_output_loss: 0.2285 - y1_output_root_mean_squared_error: 0.3320 - y2_output_root_mean_squared_error: 0.4783 - val_loss: 0.8485 - val_y1_output_loss: 0.1712 - val_y2_output_loss: 0.6600 - val_y1_output_root_mean_squared_error: 0.4185 - val_y2_output_root_mean_squared_error: 0.8206
# Epoch 484/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3402 - y1_output_loss: 0.1085 - y2_output_loss: 0.2327 - y1_output_root_mean_squared_error: 0.3297 - y2_output_root_mean_squared_error: 0.4812 - val_loss: 0.9843 - val_y1_output_loss: 0.1647 - val_y2_output_loss: 0.8005 - val_y1_output_root_mean_squared_error: 0.4091 - val_y2_output_root_mean_squared_error: 0.9038
# Epoch 485/500
# 614/614 [==============================] - 0s 103us/sample - loss: 0.3327 - y1_output_loss: 0.1007 - y2_output_loss: 0.2308 - y1_output_root_mean_squared_error: 0.3172 - y2_output_root_mean_squared_error: 0.4817 - val_loss: 0.8729 - val_y1_output_loss: 0.2334 - val_y2_output_loss: 0.6225 - val_y1_output_root_mean_squared_error: 0.4885 - val_y2_output_root_mean_squared_error: 0.7964
# Epoch 486/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3200 - y1_output_loss: 0.1056 - y2_output_loss: 0.2196 - y1_output_root_mean_squared_error: 0.3248 - y2_output_root_mean_squared_error: 0.4632 - val_loss: 1.3829 - val_y1_output_loss: 0.3743 - val_y2_output_loss: 0.9729 - val_y1_output_root_mean_squared_error: 0.6209 - val_y2_output_root_mean_squared_error: 0.9986
# Epoch 487/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.7354 - y1_output_loss: 0.1763 - y2_output_loss: 0.5585 - y1_output_root_mean_squared_error: 0.4209 - y2_output_root_mean_squared_error: 0.7471 - val_loss: 1.3546 - val_y1_output_loss: 0.3361 - val_y2_output_loss: 1.0152 - val_y1_output_root_mean_squared_error: 0.5892 - val_y2_output_root_mean_squared_error: 1.0037
# Epoch 488/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.5519 - y1_output_loss: 0.1315 - y2_output_loss: 0.4166 - y1_output_root_mean_squared_error: 0.3632 - y2_output_root_mean_squared_error: 0.6480 - val_loss: 0.8333 - val_y1_output_loss: 0.2232 - val_y2_output_loss: 0.5937 - val_y1_output_root_mean_squared_error: 0.4785 - val_y2_output_root_mean_squared_error: 0.7773
# Epoch 489/500
# 614/614 [==============================] - 0s 99us/sample - loss: 0.5317 - y1_output_loss: 0.1309 - y2_output_loss: 0.4055 - y1_output_root_mean_squared_error: 0.3504 - y2_output_root_mean_squared_error: 0.6395 - val_loss: 0.9967 - val_y1_output_loss: 0.3594 - val_y2_output_loss: 0.6188 - val_y1_output_root_mean_squared_error: 0.6105 - val_y2_output_root_mean_squared_error: 0.7900
# Epoch 490/500
# 614/614 [==============================] - 0s 107us/sample - loss: 0.3824 - y1_output_loss: 0.1077 - y2_output_loss: 0.2729 - y1_output_root_mean_squared_error: 0.3294 - y2_output_root_mean_squared_error: 0.5234 - val_loss: 0.7525 - val_y1_output_loss: 0.1997 - val_y2_output_loss: 0.5389 - val_y1_output_root_mean_squared_error: 0.4513 - val_y2_output_root_mean_squared_error: 0.7408
# Epoch 491/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3729 - y1_output_loss: 0.1028 - y2_output_loss: 0.2684 - y1_output_root_mean_squared_error: 0.3212 - y2_output_root_mean_squared_error: 0.5193 - val_loss: 0.7688 - val_y1_output_loss: 0.1817 - val_y2_output_loss: 0.5745 - val_y1_output_root_mean_squared_error: 0.4301 - val_y2_output_root_mean_squared_error: 0.7641
# Epoch 492/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.2892 - y1_output_loss: 0.0980 - y2_output_loss: 0.1945 - y1_output_root_mean_squared_error: 0.3124 - y2_output_root_mean_squared_error: 0.4378 - val_loss: 2.0238 - val_y1_output_loss: 0.4403 - val_y2_output_loss: 1.5390 - val_y1_output_root_mean_squared_error: 0.6670 - val_y2_output_root_mean_squared_error: 1.2565
# Epoch 493/500
# 614/614 [==============================] - 0s 107us/sample - loss: 0.3639 - y1_output_loss: 0.1024 - y2_output_loss: 0.2596 - y1_output_root_mean_squared_error: 0.3211 - y2_output_root_mean_squared_error: 0.5107 - val_loss: 0.8259 - val_y1_output_loss: 0.1830 - val_y2_output_loss: 0.6260 - val_y1_output_root_mean_squared_error: 0.4287 - val_y2_output_root_mean_squared_error: 0.8013
# Epoch 494/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.3252 - y1_output_loss: 0.0987 - y2_output_loss: 0.2297 - y1_output_root_mean_squared_error: 0.3148 - y2_output_root_mean_squared_error: 0.4755 - val_loss: 1.4169 - val_y1_output_loss: 0.1734 - val_y2_output_loss: 1.2030 - val_y1_output_root_mean_squared_error: 0.4212 - val_y2_output_root_mean_squared_error: 1.1133
# Epoch 495/500
# 614/614 [==============================] - 0s 107us/sample - loss: 0.4321 - y1_output_loss: 0.1197 - y2_output_loss: 0.3194 - y1_output_root_mean_squared_error: 0.3351 - y2_output_root_mean_squared_error: 0.5656 - val_loss: 1.1183 - val_y1_output_loss: 0.3923 - val_y2_output_loss: 0.7160 - val_y1_output_root_mean_squared_error: 0.6357 - val_y2_output_root_mean_squared_error: 0.8451
# Epoch 496/500
# 614/614 [==============================] - 0s 101us/sample - loss: 0.3372 - y1_output_loss: 0.1028 - y2_output_loss: 0.2320 - y1_output_root_mean_squared_error: 0.3218 - y2_output_root_mean_squared_error: 0.4833 - val_loss: 0.8228 - val_y1_output_loss: 0.1933 - val_y2_output_loss: 0.6190 - val_y1_output_root_mean_squared_error: 0.4472 - val_y2_output_root_mean_squared_error: 0.7892
# Epoch 497/500
# 614/614 [==============================] - 0s 103us/sample - loss: 0.5605 - y1_output_loss: 0.1288 - y2_output_loss: 0.4312 - y1_output_root_mean_squared_error: 0.3597 - y2_output_root_mean_squared_error: 0.6566 - val_loss: 0.8048 - val_y1_output_loss: 0.1924 - val_y2_output_loss: 0.6077 - val_y1_output_root_mean_squared_error: 0.4459 - val_y2_output_root_mean_squared_error: 0.7784
# Epoch 498/500
# 614/614 [==============================] - 0s 114us/sample - loss: 0.3523 - y1_output_loss: 0.1071 - y2_output_loss: 0.2447 - y1_output_root_mean_squared_error: 0.3283 - y2_output_root_mean_squared_error: 0.4945 - val_loss: 0.8747 - val_y1_output_loss: 0.1816 - val_y2_output_loss: 0.6720 - val_y1_output_root_mean_squared_error: 0.4319 - val_y2_output_root_mean_squared_error: 0.8295
# Epoch 499/500
# 614/614 [==============================] - 0s 103us/sample - loss: 0.3338 - y1_output_loss: 0.1065 - y2_output_loss: 0.2262 - y1_output_root_mean_squared_error: 0.3264 - y2_output_root_mean_squared_error: 0.4768 - val_loss: 0.8056 - val_y1_output_loss: 0.1946 - val_y2_output_loss: 0.5940 - val_y1_output_root_mean_squared_error: 0.4465 - val_y2_output_root_mean_squared_error: 0.7786
# Epoch 500/500
# 614/614 [==============================] - 0s 104us/sample - loss: 0.4381 - y1_output_loss: 0.1380 - y2_output_loss: 0.2999 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.5485 - val_loss: 0.8731 - val_y1_output_loss: 0.2255 - val_y2_output_loss: 0.6321 - val_y1_output_root_mean_squared_error: 0.4782 - val_y2_output_root_mean_squared_error: 0.8028

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 39us/sample - loss: 0.8731 - y1_output_loss: 0.2266 - y2_output_loss: 0.6359 - y1_output_root_mean_squared_error: 0.4782 - y2_output_root_mean_squared_error: 0.8028
# Loss = 0.8731339728677427, Y1_loss = 0.22656507790088654, Y1_mse = 0.47815534472465515, Y2_loss = 0.6359443664550781, Y2_mse = 0.8028084635734558

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
